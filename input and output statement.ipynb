# %% [markdown]
# ## input statement

# %% [raw]
# there are two methods to take  input:
# 1.raw_input()->python2
# 2.input()->python3

# %% [markdown]
# ## input()

# %% [markdown]
# read the data directly from the keyboard

# %%
x=input("enter x value")
type(x)
# Out:
# enter x value type(x)
# str

# %% [markdown]
# note->if we write only input,so by default it wil take as str

# %%
c=input("enter name")
print(c)
# Out:
# enter name chandu
# chandu

# %%
b=input("enter a number")
c=int(b)
print(c)
type(c)
# Out:
# enter a number 20
# 20
# int

# %%
type(b)
# Out:
# str

# %%
e=int(input("enter a number"))
type(e)
# Out:
# enter a number 50
# int

# %%
c=float(input("enter a num"))
type(c)
# Out:
# enter a num 10.5
# float

# %% [raw]
# ## write a program to take two input value and do

# %%
a=input("enter a num")
b=input("enter a num")
c=int(a)
d=int(b)
print("sum is :",c+d)
# Out:
# enter a num 20
# enter a num 30
# sum is : 50

# %% [markdown]
# ## how to take multiple input at a time

# %%
a,b=[int(x) for x in input("enter 2 number:").split()]
print ("product of these of this:",a*b)
# Out:
# enter 2 number: 20 30
# product of these of this: 600

# %%
a,b,c=[int(x) for x in input("enter 3 number:").split()]
print ("product of these of this:",a*b*c)
# Out:
# enter 3 number: 20 30 40
# product of these of this: 24000

# %% [markdown]
# ## eval function

# %% [raw]
# eval will take a string and evaluate the result

# %%
x=eval("14+15+200")

# %%
x
# Out:
# 229

# %%
# input of expression
x=eval(input("enter expression"))
x
# Out:
# enter expression 45+50-20+56/7
# 83.0

# %%
type(x)
# Out:
# float

# %%
l=eval(input("enter list"))
print(type(l))
# Out:
# enter list 40,20,47
# <class 'tuple'>

# %% [markdown]
# ## output statement

# %%
a,b,c,d=45,50,45,8
print(a,b,c,d,sep=",")
# Out:
# 45,50,45,8

# %% [markdown]
# ## formated string

# %%
name="chandu"
salary=25000
friend="rahul"
print("hello {0} your salary is {1} and friend is {2}".format(name,salary,friend))
print("hello {x} your salary is {y} and friend is {z}".format(x=name,y=salary,z=friend))
# Out:
# hello chandu your salary is 25000 and friend is rahul
# hello chandu your salary is 25000 and friend is rahul
