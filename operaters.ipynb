# %% [raw]
# operaters are symbules thet perform some operations.
# there are many type of operators in python.
#
# 1. artimetic operator
# 2.relational / comparison operator
# 3. logical operator
# 4. bitwise operator
# 5. assignment operator
# 6.  special operator

# %% [markdown]
# 1. artimetic operator

# %% [raw]
# + addition
# - subtraction
# * mutiplication
# / division
# % modulo
# // floor division
# ** for power/exonentials

# %%
a=10
c=20

# %%
print(a+c)
print(a-c)
print(a*c)
print(a/c)
print(a%c)
print(a//c)
print(a**c)
# Out:
# 30
# -10
# 200
# 0.5
# 10
# 0
# 100000000000000000000

# %%
a=10

# %%
10/20
# Out:
# 0.5

# %% [markdown]
# ## 2. relational operator

# %%
# code for finding out even or odd

# %% [raw]
# >,>=<,<=

# %%
a=20
b=30
print(a>b)
# Out:
# False

# %%
print(a<b)
# Out:
# True

# %%
print(a==b)
# Out:
# False

# %%
print(a>=b)
# Out:
# False

# %% [markdown]
# ## Eequality operator

# %% [raw]
# ==,!=

# %%
10==10
# Out:
# True

# %%
20==30
# Out:
# False

# %%
40!=20
# Out:
# True

# %%
30==20
# Out:
# False

# %%
"hyderabad"=="khammam"
# Out:
# False

# %%
"khammam"!="khammam"
# Out:
# False

# %% [markdown]
# ## 3.logical operator

# %% [markdown]
# and,or,not

# %% [markdown]
# and=if both arguments are True then only result is True
# or =if atleast one argument is true the result is true
# not = not true meaning

# %%
True and True
# Out:
# True

# %%
False and True
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
20 and 40
# Out:
# 40

# %%
False and False
# Out:
# False

# %%
True or Fale
# Out:
# True

# %% [raw]
# x and y
# if x is evaluates to False return x otherwise y.

# %%
0 and 20
# Out:
# 0

# %%
10 and 30
# Out:
# 30

# %% [raw]
# x or y
# if x evaluates to true then result is x otherwise result is y

# %%
10 or 20
# Out:
# 10

# %%
0 or 30
# Out:
# 30

# %%
not 30
# Out:
# False

# %%
not 0
# Out:
# True

# %%
a=20
b=30
c=40
print("and:",a<b and a<c)
print("or:0",a<b or a>c)
print("not:",not a<c)
# Out:
# and: True
# or:0 True
# not: False

# %% [markdown]
# ## Bitwise operator

# %% [raw]
# this operator can be used with interger or bool
# &,|,^,<<,>>

# %% [markdown]
# ###### condeitions

# %% [raw]
# & if both bits are 1 then only result is 1 otherwise result is 0.

# %%
bin(4)
# Out:
# '0b100'

# %%
bin(52)
# Out:
# '0b110100'

# %%
print(4&52)
# Out:
# 4

# %%
bin(10)
# Out:
# '0b1010'

# %%
bin(15)
# Out:
# '0b1111'

# %%
print(10&15)
# Out:
# 10

# %% [raw]
# | if atleast one bit is 1 then result 1 otherwise 0.

# %%
bin(20)
# Out:
# '0b10100'

# %%
bin(15)
# Out:
# '0b1111'

# %%
print(10|15)
# Out:
# 15

# %% [raw]
# ^ if bits are different then result is 1 ,otherwise 0.

# %%
print(20^15)
# Out:
# 27

# %%
bin(20)
# Out:
# '0b10100'

# %%
bin(15)
# Out:
# '0b1111'

# %%
0b10100
# Out:
# 20

# %% [raw]
# >> bitwise left shift operator

# %%
print(10<<3)
# Out:
# 80

# %%
print(10>>2)
# Out:
# 2
