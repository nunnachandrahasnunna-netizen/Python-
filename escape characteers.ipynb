# %%
da="data\nAnalytics"

# %%
print(da)
# Out:
# data
# Analytics

# %%
# \t for one tab distance
ca="graphics\tdesign"

# %%
print(ca)
# Out:
# graphics	design

# %%
# \b for backspace
gh="job\bdescription"
print(gh)
# Out:
# jodescription

# %%
jd="mani\bpopulation"

# %%
print(jd)
# Out:
# manpopulation

# %%
jd="Gmail\vpopulation"

# %%
print(jd)
# Out:
# Gmailpopulation
