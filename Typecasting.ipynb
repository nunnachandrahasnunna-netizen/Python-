# %% [markdown]
# ### Type casting

# %% [markdown]
# Converting int>float,bool,str,comp

# %%
b=2035

# %%
type(b)
# Out:
# int

# %% [markdown]
# converting int in to float

# %%
float(b)
# Out:
# 2035.0

# %% [markdown]
# convertingting in to bool

# %%
bool(b)
# Out:
# True

# %% [markdown]
# converting in to str

# %%
str(b)
# Out:
# '2035'

# %% [markdown]
# converting in to complex

# %%
complex(b)
# Out:
# (2035+0j)

# %% [markdown]
# converting float>int,bool,str,comp

# %%
k=896.30
c=0

# %%
type(k)
# Out:
# float

# %% [markdown]
# converting in to int

# %%
int(k)
# Out:
# 896

# %% [markdown]
# converting in to bool

# %%
bool(k)
# Out:
# True

# %% [markdown]
# converting in to str

# %%
str(k)
# Out:
# '896.3'

# %% [markdown]
# converting in to comp

# %%
complex(k)
# Out:
# (896.3+0j)

# %% [markdown]
# converting string>int,float,bool,complex

# %%
u='chandu'

# %%
type(u)
# Out:
# str

# %%
bool(u)
# Out:
# True

# %%
l=''

# %%
bool(l)
# Out:
# False

# %% [markdown]
# convertingcomplex>int,float,bool,str

# %%
p=58+5j

# %%
type(p)
# Out:
# complex

# %%
bool(p)
# Out:
# True

# %%
str(p)
# Out:
# '(58+5j)'
