# %% [markdown]
# ## flow control

# %% [raw]
# flow control describe the order in which the statements

# %% [markdown]
# ## types of control flow

# %% [raw]
# 1.  interative statements=for,wile
# 2. transfer statements=break,continue,pass
# 3. conditional statements=if,else,elif

# %% [markdown]
# ## conditional statement

# %% [markdown]
# ## if

# %% [raw]
# #single statement
# if,condtional:statement
# #multiple statements
# if condition:
#     statement-1
#     statement-2
#     statement-3

# %%
name="chandu"
if name=="chandu":print("hi",name)
# Out:
# hi chandu

# %%
if name=="chandu":
    print("hello",name)
    print("name+name")
    print("hi",name,"how are you?")
# Out:
# hello chandu
# name+name
# hi chandu how are you?

# %% [markdown]
# if -else condition

# %% [raw]
# if conduction:
#     statement-1
# else:
#     statement-2
#
# if conduction is true then statement-1 will be excuted,else
# statement-2 will be excuted

# %%
name=input("enter the name of guest")
if name=="chandu":
    print("hi",name,"welcome to our hote")
else:
    print("sory, mr we dont have your deatels")
# Out:
# enter the name of guest chandu
# hi chandu welcome to our hote

# %% [markdown]
# ## if-else-elif

# %% [raw]
# if conduction-1:
#     statement-1
# else conduction2:
# statement

# %%
brand=input ("what is your favourite brand?")
if brand=="kf":
    print("this is a legend brand")
elif brand=="wenshion house":
    print("this is brand of ice")
elif brand=="signature":
    print("this is my barnd")
    print("no discount")
# Out:
# what is your favourite brand? kf
# this is a legend brand

# %% [raw]
# Q1.finding out the number that belongs in between on 1 to 100
# Q2.finding out biggest/smallest number in 3m input
# q

# %%
num= int(input("enter a number:"))
if num >=1 and num <=100:
    print("the number is between 1 and 100")
# Out:
# enter a number: 100
# the number is between 1 and 100

# %%
a=int(input("enter a value"))
if a%2==0:
    print("The number is even")
else:
    print("The number is odd")
# Out:
# enter a value 25
# The number is odd
