# %% [markdown]
# # Data types

# %% [markdown]
# Data type represent the types o data present inside a variable.

# %% [markdown]
# in python we are not requaired to specify the type explicitly.

# %% [markdown]
# Based on value provide, the type will be assigned automatically.

# %% [markdown]
# i.e.dynamically typed language.

# %%
a= 10

# %%
type (a)
# Out:
# int

# %%
# no of data types(Built in) that python

# %% [markdown]
# Five fundamental data type
# - int = number
# - float decimal number
# - str = characters
# - complex =real+imag=4+7j
# - bool =True/Flase

# %% [markdown]
# # Compasite Data types

# %% [markdown]
# 1. Bytes =0-255(256)
# 2. Bytearray(format will change)
# 3. list(length of numbers,range)
# 4. tuble=()
# 5. range
# 6. set
# 7. Frozenset
# 8. dictionaty
# 9. None

# %% [markdown]
# ## int data type

# %% [markdown]
# type()=inbuilt function in python to show the data-type

# %%
a=10

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
a
# Out:
# 10

# %%
total=250
abc=300
print(total)
print(type(total))
# Out:
# 250
# <class 'int'>

# %% [markdown]
# ## we can represent int in multiple format

# %% [markdown]
# 1. Binary(base:2)
# 2. Decimal(base:10)
# 3. Octal(base:8)
# 4. Hexadecimal(base:16)

# %%
binary=0b111
decimal=1000
octal=0o456
hexa=0xA69

# %%
binary
# Out:
# 7

# %%
hexa
# Out:
# 2665

# %%
a=255

# %%
bin(a),oct(a),hex(a)
# Out:
# ('0b11111111', '0o377', '0xff')

# %% [markdown]
# #### Binary to all

# %%
b=0b1111111

# %%
b,oct(b),hex(b)
# Out:
# (127, '0o177', '0x7f')

# %% [markdown]
# ### Octal to all

# %%
c=0o2435

# %%
c,bin(c),hex(c)
# Out:
# (1309, '0b10100011101', '0x51d')

# %% [markdown]
# ### Hex to all

# %% [markdown]
# ## float

# %%
a=45.65

# %%
type (a)
# Out:
# float

# %% [markdown]
# ## Complex

# %%
x=6+8j

# %%
type(x)
# Out:
# complex

# %%
x.real
# Out:
# 6.0

# %%
x.imag
# Out:
# 8.0

# %% [markdown]
# ## string

# %%
name='chandu'
name2="Nnna"

# %%
print(name)
# Out:
# chandu

# %%
print(name2)
# Out:
# Nnna

# %% [markdown]
# ## writting comment in python

# %% [raw]
# 1. using # you can write comment
# 2. using 'comment' you can write comment single line
# 3. using "comment" you can write
# 4. using "comment"" for mul

# %% [markdown]
# ### bool

# %%
a=True
print(type(a))
# Out:
# <class 'bool'>

# %%
a=20

# %%
b=20

# %%
c=45

# %%
a is c
# Out:
# False

# %%
a is b
# Out:
# True

# %%
a is b
# Out:
# True

# %%
id(a)
# Out:
# 140706300999176

# %%
id(b)
# Out:
# 140706300999176

# %%
a is b
# Out:
# True
